# %% [markdown]
# # Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## load dataset

# %%
Titanic = pd.read_csv('Titanic.csv')
Titanic
# Out:
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
# 891           d        d      d
# 892         889        0      3
#
#                                                   Name     Sex  Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38     1
# 2                               Heikkinen, Miss. Laina  female   26     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35     1
# 4                             Allen, Mr. William Henry    male   35     0
# ..                                                 ...     ...  ...   ...
# ...

# %%
Titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 893 entries, 0 to 892
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  893 non-null    object
#  1   Survived     893 non-null    object
#  2   Pclass       893 non-null    object
#  3   Name         893 non-null    object
#  4   Sex          893 non-null    object
#  5   Age          715 non-null    object
#  6   SibSp        893 non-null    object
#  7   Parch        893 non-null    object
#  8   Ticket       893 non-null    object
#  9   Fare         893 non-null    object
#  10  Cabin        205 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: object(12)
# memory usage: 83.8+ KB

# %%
Titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            178
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          688
# Embarked         2
# dtype: int64

# %%
Titanic['Survived'].unique()
# Out:
# array(['0', '1', 'd'], dtype=object)

# %%
Titanic['Pclass'].unique()
# Out:
# array(['3', '1', '2', 'd'], dtype=object)

# %%
Titanic['Sex'].unique()
# Out:
# array(['male', 'female', 'd'], dtype=object)

# %%
Titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan, 'd'], dtype=object)

# %%
del Titanic['Cabin']

# %%
Titanic
# Out:
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
# 891           d        d      d
# 892         889        0      3
#
#                                                   Name     Sex  Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38     1
# 2                               Heikkinen, Miss. Laina  female   26     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35     1
# 4                             Allen, Mr. William Henry    male   35     0
# ..                                                 ...     ...  ...   ...
# ...

# %%
del Titanic['Age']

# %%
Titanic
# Out:
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
# 891           d        d      d
# 892         889        0      3
#
#                                                   Name     Sex SibSp Parch  \
# 0                              Braund, Mr. Owen Harris    male     1     0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female     1     0
# 2                               Heikkinen, Miss. Laina  female     0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     1     0
# 4                             Allen, Mr. William Henry    male     0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
Titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
Titanic[Titanic['Embarked'].isnull()]
# Out:
#     PassengerId Survived Pclass                                       Name  \
# 61           62        1      1                        Icard, Miss. Amelie
# 829         830        1      1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex SibSp Parch  Ticket Fare Embarked
# 61   female     0     0  113572   80      NaN
# 829  female     0     0  113572   80      NaN

# %%
Pclass1 = Titanic[Titanic['Pclass'] == 1]
Pclass1
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
counts = Pclass1['Embarked'].value_counts()
counts
# Out:
# Series([], Name: count, dtype: int64)

# %%
Titanic.groupby('Pclass')['Embarked'].agg(pd.Series.mode)
# Out:
# Pclass
# 1    S
# 2    S
# 3    S
# d    d
# Name: Embarked, dtype: object

# %%
Titanic.loc[(Titanic['Embarked'].isnull()),'Embarked'] = 'S'

# %%
Titanic[Titanic['Embarked'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
Titanic
# Out:
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
# 891           d        d      d
# 892         889        0      3
#
#                                                   Name     Sex SibSp Parch  \
# 0                              Braund, Mr. Owen Harris    male     1     0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female     1     0
# 2                               Heikkinen, Miss. Laina  female     0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     1     0
# 4                             Allen, Mr. William Henry    male     0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
Titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
Titanic[Titanic.duplicated()]
# Out:
#     PassengerId Survived Pclass                                      Name  \
# 892         889        0      3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex SibSp Parch      Ticket   Fare Embarked
# 892  female     1     2  W./C. 6607  23.45        S

# %%
Titanic = Titanic.drop([892])

# %%
duplicate_rows = Titanic[Titanic.duplicated()]
duplicate_indices = duplicate_rows.index
Titanic_clean = Titanic.drop(duplicate_indices)
Titanic_clean
# Out:
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 887         888        1      1
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
# 891           d        d      d
#
#                                                   Name     Sex SibSp Parch  \
# 0                              Braund, Mr. Owen Harris    male     1     0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female     1     0
# 2                               Heikkinen, Miss. Laina  female     0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     1     0
# 4                             Allen, Mr. William Henry    male     0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
Titanic_clean[Titanic_clean.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
Titanic[Titanic.duplicated()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, SibSp, Parch, Ticket, Fare, Embarked]
# Index: []

# %%
Titanic
# Out:
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 887         888        1      1
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
# 891           d        d      d
#
#                                                   Name     Sex SibSp Parch  \
# 0                              Braund, Mr. Owen Harris    male     1     0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female     1     0
# 2                               Heikkinen, Miss. Laina  female     0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     1     0
# 4                             Allen, Mr. William Henry    male     0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
Titanic = Titanic.drop([891])

# %%
Titanic
# Out:
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 886         887        0      2
# 887         888        1      1
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
#
#                                                   Name     Sex SibSp Parch  \
# 0                              Braund, Mr. Owen Harris    male     1     0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female     1     0
# 2                               Heikkinen, Miss. Laina  female     0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female     1     0
# 4                             Allen, Mr. William Henry    male     0     0
# ..                                                 ...     ...   ...   ...
# ...

# %%
plt.figure(figsize=(2,3))
plt.hist(Titanic['Survived'], bins=2, color = 'blue', edgecolor = 'red')
plt.xlabel('died / survived')
plt.ylabel('count')
plt.title('Survived HISTO chart')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Titanic['Sex'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Sex'>

# %%
Pclass_Sum = Titanic.groupby('Pclass')['Pclass'].agg(pd.Series.count)
Pclass_Sum
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
Pclass_sum = Titanic['Pclass'].value_counts()
Pclass_sum
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
plt.figure(figsize=(2,3))
plt.hist(Titanic['Pclass'], bins=3, color = 'pink', edgecolor = 'red')
plt.title('Passenger class HISTO chart')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(5,3))
plt.bar(Pclass_sum.index, 'Pclass_sum', color = 'yellow', edgecolor = 'red')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Pclass BAR chart')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Cabin_with_b = df[df['Cabin'].str.startswith('B') & pd.notna(df['Cabin'])]
#Cabin_with_b

# %%
#df[(df['Pclass'] == 1) & (df['Fare'] == 80)]
#df[(df['Pclass'] == 1) & (df['Fare'] >= 75) & (df['Fare'] <= 80)]
